# %% [markdown]
# ## Preparing the Enviroment

# %%
# !pip install tqdm notebook==7.1.2 openai elasticsearch pandas scikit-learn ipywidgets
# Out:
# Requirement already satisfied: tqdm in /home/elegant00/miniconda3/lib/python3.10/site-packages (4.65.0)
# Collecting notebook==7.1.2
#   Downloading notebook-7.1.2-py3-none-any.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 7.4 MB/s eta 0:00:00a 0:00:01m
# Collecting openai
#   Downloading openai-1.35.13-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.5/328.5 kB 78.2 MB/s eta 0:00:00
# Collecting elasticsearch
#   Downloading elasticsearch-8.14.0-py3-none-any.whl (480 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.2/480.2 kB 88.2 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 62.3 MB/s eta 0:00:0000:0100:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 65.5 MB/s eta 0:00:00a 0:00:01
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.3-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 65.5 MB/s eta 0:00:00
# Collecting notebook-shim<0.3,>=0.2
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.14.1-py3-none-any.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 69.7 MB/s eta 0:00:00
# Collecting jupyterlab-server<3,>=2.22.1
#   Downloading jupyterlab_server-2.27.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 25.2 MB/s eta 0:00:00
# Collecting jupyterlab<4.2,>=4.1.1
#   Downloading jupyterlab-4.1.8-py3-none-any.whl (11.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 29.2 MB/s eta 0:00:0000:010:01
# Collecting tornado>=6.2.0
#   Downloading tornado-6.4.1-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (436 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.8/436.8 kB 49.4 MB/s eta 0:00:00
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 52.6 MB/s eta 0:00:00
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 35.1 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from openai) (4.12.2)
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 29.1 MB/s eta 0:00:00
# Collecting elastic-transport<9,>=8.13
#   Downloading elastic_transport-8.13.1-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 22.4 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 50.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from pandas) (2.9.0)
# Collecting numpy>=1.22.4
#   Downloading numpy-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 44.5 MB/s eta 0:00:0000:0100:01
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 61.4 MB/s eta 0:00:00
# Collecting scipy>=1.6.0
#   Downloading scipy-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 MB 42.4 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 61.0 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: comm>=0.1.3 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Collecting jupyterlab-widgets~=3.0.11
#   Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 48.8 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0.11
#   Downloading widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 52.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ipython>=6.1.0 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipywidgets) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: idna>=2.8 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /home/elegant00/miniconda3/lib/python3.10/site-packages (from elastic-transport<9,>=8.13->elasticsearch) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from elastic-transport<9,>=8.13->elasticsearch) (1.26.15)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 33.2 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: jedi>=0.16 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting nbformat>=5.3.0
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 29.5 MB/s eta 0:00:00
# Collecting prometheus-client>=0.9
#   Downloading prometheus_client-0.20.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq>=24 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.1.2) (25.1.2)
# Collecting websocket-client>=1.7
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 27.3 MB/s eta 0:00:00
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-7.16.4-py3-none-any.whl (257 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 51.7 MB/s eta 0:00:00
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: packaging>=22.0 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.1.2) (23.0)
# Collecting jinja2>=3.0.3
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 58.1 MB/s eta 0:00:00
# Collecting jupyter-events>=0.9.0
#   Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook==7.1.2) (5.7.2)
# Collecting jupyter-client>=7.4.4
#   Downloading jupyter_client-8.6.2-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 27.4 MB/s eta 0:00:00
# Collecting tomli>=1.2.2
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 25.9 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=6.5.0 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook==7.1.2) (6.29.5)
# Collecting json5>=0.9.0
#   Downloading json5-0.9.25-py3-none-any.whl (30 kB)
# Collecting requests>=2.31
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 28.7 MB/s eta 0:00:00
# Collecting jsonschema>=4.18.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 38.8 MB/s eta 0:00:00
# Collecting babel>=2.10
#   Downloading Babel-2.15.0-py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 48.0 MB/s eta 0:00:00a 0:00:01
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.20.1
#   Downloading pydantic_core-2.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 48.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.5 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 30.1 MB/s eta 0:00:00
# Requirement already satisfied: debugpy>=1.6.5 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook==7.1.2) (1.6.7)
# Requirement already satisfied: nest-asyncio in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook==7.1.2) (1.6.0)
# Requirement already satisfied: psutil in /home/elegant00/miniconda3/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook==7.1.2) (5.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 25.7 MB/s eta 0:00:00
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (355 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.8/355.8 kB 71.4 MB/s eta 0:00:00
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: platformdirs>=2.5 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook==7.1.2) (4.2.2)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting pyyaml>=5.3
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 60.4 MB/s eta 0:00:00
# Collecting bleach!=5.0.0
#   Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.8/162.8 kB 51.0 MB/s eta 0:00:00
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 24.8 MB/s eta 0:00:00
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 19.0 MB/s eta 0:00:00
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.0-py3-none-any.whl (25 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting tinycss2
#   Downloading tinycss2-1.3.0-py3-none-any.whl (22 kB)
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/elegant00/miniconda3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook==7.1.2) (2.0.4)
# Requirement already satisfied: pure-eval in /home/elegant00/miniconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: jsonpointer>1.13 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook==7.1.2) (2.1)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-24.6.0-py3-none-any.whl (14 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/elegant00/miniconda3/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.1.2) (1.15.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: pycparser in /home/elegant00/miniconda3/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.1.2) (2.21)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 30.3 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Installing collected packages: webencodings, pytz, fastjsonschema, widgetsnbextension, websocket-client, webcolors, uri-template, tzdata, types-python-dateutil, tornado, tomli, tinycss2, threadpoolctl, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, requests, pyyaml, python-json-logger, pydantic-core, prometheus-client, pandocfilters, overrides, numpy, mistune, MarkupSafe, jupyterlab-widgets, jupyterlab-pygments, json5, joblib, h11, fqdn, elastic-transport, distro, defusedxml, bleach, babel, attrs, async-lru, annotated-types, terminado, scipy, referencing, pydantic, pandas, jupyter-client, jinja2, httpcore, elasticsearch, beautifulsoup4, arrow, argon2-cffi-bindings, anyio, scikit-learn, jupyter-server-terminals, jsonschema-specifications, isoduration, httpx, argon2-cffi, openai, jsonschema, ipywidgets, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 7.3.4
#     Uninstalling jupyter-client-7.3.4:
#       Successfully uninstalled jupyter-client-7.3.4
# Successfully installed MarkupSafe-2.1.5 annotated-types-0.7.0 anyio-4.4.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-23.2.0 babel-2.15.0 beautifulsoup4-4.12.3 bleach-6.1.0 defusedxml-0.7.1 distro-1.9.0 elastic-transport-8.13.1 elasticsearch-8.14.0 fastjsonschema-2.20.0 fqdn-1.5.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 ipywidgets-8.1.3 isoduration-20.11.0 jinja2-3.1.4 joblib-1.4.2 json5-0.9.25 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 jupyter-client-8.6.2 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.1 jupyter-server-terminals-0.5.3 jupyterlab-4.1.8 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.2 jupyterlab-widgets-3.0.11 mistune-3.0.2 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 notebook-7.1.2 notebook-shim-0.2.4 numpy-2.0.0 openai-1.35.13 overrides-7.7.0 pandas-2.2.2 pandocfilters-1.5.1 prometheus-client-0.20.0 pydantic-2.8.2 pydantic-core-2.20.1 python-json-logger-2.0.7 pytz-2024.1 pyyaml-6.0.1 referencing-0.35.1 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.19.0 scikit-learn-1.5.1 scipy-1.14.0 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.5 terminado-0.18.1 threadpoolctl-3.5.0 tinycss2-1.3.0 tomli-2.0.1 tornado-6.4.1 types-python-dateutil-2.9.0.20240316 tzdata-2024.1 uri-template-1.3.0 webcolors-24.6.0 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.11

# %%
import minsearch
import json
